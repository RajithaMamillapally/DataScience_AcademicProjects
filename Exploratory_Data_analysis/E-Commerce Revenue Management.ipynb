# %% [markdown]
# #I have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# #Before starting analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 10

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
path=("/content/drive/MyDrive/E-Commerce.csv")
ECom_Data=pd.read_csv(path)

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data.
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information.
# ## c)	How many object data types are there?
# ## d)	Is there any Boolean data type?
# #### Note: Use the markdown feature of Python to explain your answer.

# %%
ECom_Data.head(10) #for printing 1st 10 rows of the data
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %% [markdown]
# #### Ans 1 a)

# %%
ECom_Data.tail(10) #for printing last 10 rows of the data
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8896             04-12-2020     04-12-2020
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %% [markdown]
# #### Ans 1 b)

# %%
ECom_Data.shape
# Out:
# (8906, 17)

# %% [markdown]
# # There are 8906 Rows and 17 Columns in the above data

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# #### Ans  1 c)

# %% [markdown]
# # There are 14 object data types are in the given dataset

# %% [markdown]
# ### Ans 1 d)

# %% [markdown]
# # There is no Boolean data type in the given dataset

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description.
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)

# %%
df=ECom_Data.drop(["product_specifications","description"],axis=1,inplace=True)

# %% [markdown]
# ### Ans 2 b)

# %% [markdown]
# # inplace=True is used to permanently remove specified rows or columns in the data set
#
# ECom_Data.drop(columns=["product_specifications","description"],axis=1,inplace=True)

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Apparently, such simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at Brand level.
# ## a) How many unique Brand are there?
# ## b) Note that each Brand contains multiple products. Show the average product_rating within each Brand

# %% [markdown]
# ### Ans 3 a)

# %%
ECom_Data.Brand.nunique()
# Out:
# 2571

# %% [markdown]
# ### Ans 3 b)

# %%
ECom_Data.groupby(["Brand"])["product_rating"].mean()
# Out:
# Brand
# 1OAK            1.500000
# 3A AUTOCARE     3.268293
# 3D Mat          3.000000
# 3kFactory       2.000000
# 4D              3.600000
#                   ...
# youniqueshop    2.000000
# zDelhi.com      5.000000
# zaidis          4.000000
# zasmina         4.500000
#  Tarkan         5.000000
# Name: product_rating, Length: 2571, dtype: float64

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category.
#
# ### Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s)  maximum and minimum orders were placed.
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order?

# %% [markdown]
# ### Ans 4 a)

# %%
plt.figure(figsize=(7,4))
plt.title("Barplot:Product Category type")
sns.countplot(x=ECom_Data["product_main_category"],order=ECom_Data["product_main_category"].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel("Product Category type")
# Out:
# Text(0.5, 0, 'Product Category type')

# %% [markdown]
# ### Ans 4 b)

# %% [markdown]
# ## ***From the above Bar plot,below are the findings:***
# # Maximum orders were placed for Clothing
# #minimum orders were placed for Wearable Smart Devices

# %% [markdown]
# ### Ans 4 c)

# %%
ECom_Data.value_counts("product_main_category",ascending=False).head()
# Out:
# product_main_category
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# dtype: int64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue: </font>
#
# ####     The company charges
# ####  (i) 25% on the orders having final price (discounted price) greater than 600
#
# #### (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
#
# #### (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
#
# #### (iv) Otherwise, 5% on the final price (discounted price)    </font>

# %% [markdown]
# ## Q 5. Find the Total Revenue generated by the E-Commerce company over all orders placed.
#
# #### Hint: Calculate revenue of E-commerce company using the conditions mentioned above and then do the total (sum) of all to get total Revenue.

# %% [markdown]
# ### Ans 5

# %%
ECom_Data["Revenue1"]=ECom_Data[ECom_Data["discounted_price"]>600]["discounted_price"]*25/100

# %%
ECom_Data["Revenue2"]=ECom_Data[(ECom_Data["discounted_price"]>350) & (ECom_Data["discounted_price"]<=600)] ["discounted_price"]*15/100

# %%
ECom_Data["Revenue3"]=ECom_Data[(ECom_Data["discounted_price"]>100) & (ECom_Data["discounted_price"]<=350)] ["discounted_price"]*10/100

# %%
ECom_Data["Revenue4"]=ECom_Data[ECom_Data["discounted_price"]<=100]["discounted_price"]*5/100

# %%
ECom=ECom_Data.fillna(0)

# %%
ECom["Revenue"]=ECom["Revenue1"]+ECom["Revenue2"]+ECom["Revenue3"]+ECom["Revenue4"]

# %%
ECom["Revenue"].sum()
# Out:
# 2217486.85

# %% [markdown]
# # Total Revenue generated by the E-Commerce company over all the orders placed is 2217486.85

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order
# #### Hint: Total BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's revenue.
# #### Brand Revenue is the discounted price minus the Revenue (generated using the conditions given above Q5)

# %% [markdown]
# ### Ans 6

# %%
ECom["Brand Revenue"]=ECom["discounted_price"]-ECom["Revenue"]

# %%
ECom["Brand Revenue"].sum()
# Out:
# 7522992.15

# %% [markdown]
# #Total Brand Revenue value is 7522992.15

# %%
ECom.groupby(["Brand"])["Brand Revenue"].sum().sort_values(ascending=False).head(10)
# Out:
# Brand
# Allure Auto     498464.25
# GAGA            237390.00
# Slim            212062.60
# DailyObjects    181980.00
# Diviniti        143115.00
# Regular         126112.35
# Enthopia        123146.25
# TheLostPuppy    116595.35
# Asus             99241.50
# Springwel        88978.50
# Name: Brand Revenue, dtype: float64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices for each product.
#
# ## a)	Draw boxplots of retail_price & discounted_price.
#
# ## b)	 Are there any outliers? (Yes/No)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis)

# %% [markdown]
# ### Ans 7 a)

# %%
plt.figure(figsize=(4,3))
sns.boxplot(data=ECom,x="retail_price");

# %%
plt.figure(figsize=(4,3))
sns.boxplot(data=ECom,x="discounted_price");

# %% [markdown]
# ### Ans 7 b)

# %% [markdown]
# # Yes, there are outliers

# %% [markdown]
# ### Ans 7 c)

# %%
sns.scatterplot(data=ECom,x="retail_price",y="discounted_price");

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the Brand specific information as stated:
# ## i.	total number of orders placed per Brand
# ## ii.	total retail_price per Brand
# ## iii.	total discounted_price per Brand, and
# ## iv.	total BrandRevenue generated per Brand.
#
# ## Also, draw a pairplot using these four features.

# %% [markdown]
# ### Ans 8

# %%
No_of_orders=ECom["Brand"].value_counts()
print(No_of_orders)
# Out:
# Allure Auto        469
# Regular            299
# Slim               267
# TheLostPuppy       229
# Black              147
#                   ...
# Cello Furniture      1
# Schwarzkopf          1
# Flair                1
# Ruby                 1
# Ambika Lahenga       1
# Name: Brand, Length: 2571, dtype: int64

# %%
Total_retail_price=ECom.groupby(["Brand"])["retail_price"].sum()
print(Total_retail_price)
# Out:
# Brand
# 1OAK              1698
# 3A AUTOCARE     107059
# 3D Mat            7250
# 3kFactory          399
# 4D               17500
#                  ...
# youniqueshop       810
# zDelhi.com        4499
# zaidis             150
# zasmina           1400
#  Tarkan           1999
# Name: retail_price, Length: 2571, dtype: int64

# %%
Total_discounted_price=ECom.groupby(["Brand"])["discounted_price"].sum()
print(Total_discounted_price)
# Out:
# Brand
# 1OAK             1274
# 3A AUTOCARE     74134
# 3D Mat           6999
# 3kFactory         174
# 4D               7948
#                 ...
# youniqueshop      640
# zDelhi.com       3999
# zaidis            129
# zasmina           639
#  Tarkan           349
# Name: discounted_price, Length: 2571, dtype: int64

# %%
Total_brand_revenue=ECom.groupby(["Brand"])["Brand Revenue"].sum()
print(Total_brand_revenue)
# Out:
# Brand
# 1OAK             1015.40
# 3A AUTOCARE     55647.90
# 3D Mat           5249.25
# 3kFactory         156.60
# 4D               5961.00
#                   ...
# youniqueshop      480.00
# zDelhi.com       2999.25
# zaidis            116.10
# zasmina           575.10
#  Tarkan           314.10
# Name: Brand Revenue, Length: 2571, dtype: float64

# %%
df=pd.DataFrame(columns=["Total_retail_price","Total_brand_revenue","Total_discounted_price","No_of_orders"])
df["Total_retail_price"]=Total_retail_price
df["Total_brand_revenue"]=Total_brand_revenue
df["Total_discounted_price"]=Total_discounted_price
df["No_of_orders"]=No_of_orders
df.head()
# Out:
#              Total_retail_price  Total_brand_revenue  Total_discounted_price  \
# Brand
# 1OAK                       1698              1015.40                    1274
# 3A AUTOCARE              107059             55647.90                   74134
# 3D Mat                     7250              5249.25                    6999
# 3kFactory                   399               156.60                     174
# 4D                        17500              5961.00                    7948
#
#              No_of_orders
# Brand
# 1OAK                    2
# 3A AUTOCARE            41
# 3D Mat                  1
# 3kFactory               1
# 4D                      5

# %%
plt.figure(figsize=(3,2))
sns.pairplot(data=df,vars=["Total_retail_price","Total_brand_revenue","Total_discounted_price","No_of_orders"],corner=True);

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately.
#
# ## b)	Identify the best and the worst performing months for each region.
#
# #### Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days

# %% [markdown]
# ### Ans 9 a)

# %%
df1=pd.DataFrame()
ECom["Order_Date"]=pd.to_datetime(ECom.Order_Date,format="%d-%m-%Y")
df1["Order_month"]=ECom["Order_Date"].dt.strftime("%y %m")
df1["Revenue"]=ECom["Revenue"].copy()
df1["Region"]=ECom["Region"].copy()
df2=pd.DataFrame(df1.groupby(["Region","Order_month"])["Revenue"].sum())
df2.head()
# Out:
#                       Revenue
# Region Order_month
# East   20 12        363413.85
#        21 01        218740.60
#        21 02         14347.25
#        21 03        124934.10
#        21 04         56293.05

# %%
df2.sort_values(by="Order_month",ascending=True,inplace=True)
plt.figure(figsize=(10,5))
sns.lineplot(data=df2,x="Order_month",y="Revenue",hue="Region",markers=True);

# %% [markdown]
# ### Ans 9 b)

# %% [markdown]
# # For East region:
# Best performing mmonth is ***December 2020*** &
# Worst performing month is ***October 2021***
# # For West Region:
# Best performing month is ***December 2020*** &
# Worst performing month is ***October 2021***
# # For North Region:
# Best performing month is ***December 2020*** &
# Worst performing month is ***August 2021***
# # For South Region:
# Best performing month is ***December2020*** &
# Worst performing month is ***May 2021***
